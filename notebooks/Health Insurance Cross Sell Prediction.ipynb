# %% [markdown]
# # `Health Insurance Cross Sell Prediction`

# %% [markdown]
# Our client is an Insurance company that has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders (customers) from past year will also be interested in Vehicle Insurance provided by the company.
#
# An insurance policy is an arrangement by which a company undertakes to provide a guarantee of compensation for specified loss, damage, illness, or death in return for the payment of a specified premium. A premium is a sum of money that the customer needs to pay regularly to an insurance company for this guarantee.
#
# For example, you may pay a premium of Rs. 5000 each year for a health insurance cover of Rs. 200,000/- so that if, God forbid, you fall ill and need to be hospitalised in that year, the insurance provider company will bear the cost of hospitalisation etc. for upto Rs. 200,000. Now if you are wondering how can company bear such high hospitalisation cost when it charges a premium of only Rs. 5000/-, that is where the concept of probabilities comes in picture. For example, like you, there may be 100 customers who would be paying a premium of Rs. 5000 every year, but only a few of them (say 2-3) would get hospitalised that year and not everyone. This way everyone shares the risk of everyone else.
#
# Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of unfortunate accident by the vehicle, the insurance provider company will provide a compensation (called ‘sum assured’) to the customer.
#
# Building a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimise its business model and revenue.
#
# Now, in order to predict, whether the customer would be interested in Vehicle insurance, you have information about demographics (gender, age, region code type), Vehicles (Vehicle Age, Damage), Policy (Premium, sourcing channel) etc.

# %%
import numpy as np
import pandas as pd
#import mlflow
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import warnings
import ipywidgets as widgets
from IPython.display import display
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, cross_val_predict
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, OrdinalEncoder, LabelEncoder
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.classifier import ROCAUC


#mlflow.set_tracking_uri("sqlite:///mlflow.db")
#mlflow.set_experiment("health-insurance-cross-sell-detection")
warnings.filterwarnings('ignore')
pd.options.display.max_columns=None

# %%
train_df = pd.read_csv("../data/raw/train.csv")

# %%
train_df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0        > 2 Years            Yes         40454.0                  26.0
# 1         1-2 Year             No         33536.0                  26.0
# 2        > 2 Years            Yes         38294.0                  26.0
# 3         < 1 Year             No         28619.0                 152.0
# 4         < 1 Year             No         27496.0                 152.0
# ...            ...            ...             ...                   ...
# 381104    1-2 Year             No         30170.0                  26.0
# 381105    < 1 Year             No         40016.0                 152.0
# 381106    < 1 Year             No         35118.0                 160.0
# 381107   > 2 Years            Yes         44617.0                 124.0
# 381108    1-2 Year             No         41777.0                  26.0
#
#         Vintage  Response
# 0           217         1
# 1           183         0
# 2            27         1
# 3           203         0
# 4            39         0
# ...         ...       ...
# 381104       88         0
# 381105      131         0
# 381106      161         0
# 381107       74         0
# 381108      237         0
#
# [381109 rows x 12 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
train_df.describe().T
# Out:
#                          count           mean            std     min      25%  \
# id                    381109.0  190555.000000  110016.836208     1.0  95278.0
# Age                   381109.0      38.822584      15.511611    20.0     25.0
# Driving_License       381109.0       0.997869       0.046110     0.0      1.0
# Region_Code           381109.0      26.388807      13.229888     0.0     15.0
# Previously_Insured    381109.0       0.458210       0.498251     0.0      0.0
# Annual_Premium        381109.0   30564.389581   17213.155057  2630.0  24405.0
# Policy_Sales_Channel  381109.0     112.034295      54.203995     1.0     29.0
# Vintage               381109.0     154.347397      83.671304    10.0     82.0
# Response              381109.0       0.122563       0.327936     0.0      0.0
#
#                            50%       75%       max
# id                    190555.0  285832.0  381109.0
# Age                       36.0      49.0      85.0
# Driving_License            1.0       1.0       1.0
# Region_Code               28.0      35.0      52.0
# Previously_Insured         0.0       1.0       1.0
# Annual_Premium         31669.0   39400.0  540165.0
# Policy_Sales_Channel     133.0     152.0     163.0
# Vintage                  154.0     227.0     299.0
# Response                   0.0       0.0       1.0

# %%
train_df.isna().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
train_df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Inference
#      * The Data don't have any null and duplicated values

# %% [markdown]
# ## `EDA`

# %%
def value_count_norm(df, feature):
    value_count = df[feature].value_counts()
    value_count_norm_1 = df[feature].value_counts(normalize=True) * 100
    value_count_norm_1_concat = pd.concat([value_count, value_count_norm_1], axis=1)
    value_count_norm_1_concat.columns = ['Count', 'Frequency %']
    return value_count_norm_1_concat

# %%
def create_pie_chart(df, feature):
    n = len(value_count_norm(df, feature).index)
    colors = sns.color_palette('pastel')[0:n]
    plt.pie(value_count_norm(df, feature).iloc[:, 1],
            colors = colors, autopct='%1.2f%%', 
            labels=value_count_norm(df, feature).index)
    plt.title('{}'.format(feature))
    return plt.show()

# %%
def create_hist_plot(df, feature):
    figure(figsize=(20, 8))
    sns.histplot(df[feature], kde=True)
    plt.title('{}'.format(feature))
    return plt.show()

# %%
train_df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
def get_info(df, feature):
    match feature:
        case 'Gender'|'Driving_License'|'Region_Code'|'Previously_Insured'|'Vehicle_Damage'|'Vehicle_Age':
            print('Description:\n{}'.format(df[feature].describe()))
            print('*'*50)
            print('Object type:\n{}'.format(df[feature].dtype))
            print('*'*50)
            print('Value count:\n{}'.format(value_count_norm(df, feature)))
        case 'Age'|'Region_Code'|'Annual_Premium'|'Policy_Sales_Channel'|'Vintage'|'Region_Code':
            print('Description:\n{}'.format((np.abs(df[feature])).describe()))
            print('*'*50)
            print('Object type:{}'.format(df[feature].dtype))
        case _:
            print('Error')

# %%
def get_report(df, feature):
    match feature:
        case 'Gender'|'Driving_License'|'Previously_Insured'|'Vehicle_Damage'|'Vehicle_Age':
            get_info(df, feature)
            print('*'*50)
            create_pie_chart(df, feature)
        case 'Age'|'Region_Code'|'Annual_Premium'|'Policy_Sales_Channel'|'Vintage':
            get_info(df, feature)
            print('*'*50)
            create_hist_plot(df, feature)
        case _:
            print("Error")

# %%
get_report(train_df, 'Gender')
# Out:
# Description:
# count     381109
# unique         2
# top         Male
# freq      206089
# Name: Gender, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#          Count  Frequency %
# Male    206089     54.07613
# Female  175020     45.92387
# **************************************************

# %%
get_report(train_df, 'Vehicle_Age')
# Out:
# Description:
# count       381109
# unique           3
# top       1-2 Year
# freq        200316
# Name: Vehicle_Age, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#             Count  Frequency %
# 1-2 Year   200316    52.561341
# < 1 Year   164786    43.238549
# > 2 Years   16007     4.200111
# **************************************************

# %%
get_report(train_df, 'Driving_License')
# Out:
# Description:
# count    381109.000000
# mean          0.997869
# std           0.046110
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Driving_License, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#     Count  Frequency %
# 1  380297    99.786938
# 0     812     0.213062
# **************************************************

# %%
get_report(train_df, 'Previously_Insured')
# Out:
# Description:
# count    381109.000000
# mean          0.458210
# std           0.498251
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: Previously_Insured, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#     Count  Frequency %
# 0  206481    54.178988
# 1  174628    45.821012
# **************************************************

# %%
get_report(train_df, 'Vehicle_Damage')
# Out:
# Description:
# count     381109
# unique         2
# top          Yes
# freq      192413
# Name: Vehicle_Damage, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#       Count  Frequency %
# Yes  192413    50.487656
# No   188696    49.512344
# **************************************************

# %%
get_report(train_df, 'Age')
# Out:
# Description:
# count    381109.000000
# mean         38.822584
# std          15.511611
# min          20.000000
# 25%          25.000000
# 50%          36.000000
# 75%          49.000000
# max          85.000000
# Name: Age, dtype: float64
# **************************************************
# Object type:int64
# **************************************************

# %%
get_report(train_df, 'Region_Code')
# Out:
# Description:
# count    381109.000000
# mean         26.388807
# std          13.229888
# min           0.000000
# 25%          15.000000
# 50%          28.000000
# 75%          35.000000
# max          52.000000
# Name: Region_Code, dtype: float64
# **************************************************
# Object type:
# float64
# **************************************************
# Value count:
#        Count  Frequency %
# 28.0  106415    27.922458
# 8.0    33877     8.889058
# 46.0   19749     5.181982
# 41.0   18263     4.792067
# 15.0   13308     3.491914
# 30.0   12191     3.198822
# 29.0   11065     2.903369
# 50.0   10243     2.687683
# 3.0     9251     2.427390
# 11.0    9232     2.422404
# 36.0    8797     2.308264
# 33.0    7654     2.008349
# 47.0    7436     1.951148
# 35.0    6942     1.821526
# 6.0     6280     1.647823
# 45.0    5605     1.470708
# 37.0    5501     1.443419
# 18.0    5153     1.352107
# 48.0    4681     1.228258
# 14.0    4678     1.227470
# 39.0    4644     1.218549
# 10.0    4374     1.147703
# 21.0    4266     1.119365
# 2.0     4038     1.059539
# 13.0    4036     1.059015
# 7.0     3279     0.860384
# 12.0    3198     0.839130
# 9.0     3101     0.813678
# 27.0    2823     0.740733
# 32.0    2787     0.731287
# 43.0    2639     0.692453
# 17.0    2617     0.686680
# 26.0    2587     0.678808
# 25.0    2503     0.656767
# 24.0    2415     0.633677
# 38.0    2026     0.531606
# 0.0     2021     0.530294
# 16.0    2007     0.526621
# 31.0    1960     0.514289
# 23.0    1960     0.514289
# 20.0    1935     0.507729
# 49.0    1832     0.480702
# 4.0     1801     0.472568
# 34.0    1664     0.436620
# 19.0    1535     0.402772
# 22.0    1309     0.343471
# 40.0    1295     0.339798
# 5.0     1279     0.335600
# 1.0     1008     0.264491
# 44.0     808     0.212013
# 42.0     591     0.155074
# 52.0     267     0.070059
# 51.0     183     0.048018
# **************************************************

# %%
get_report(train_df, 'Vintage')
# Out:
# Description:
# count    381109.000000
# mean        154.347397
# std          83.671304
# min          10.000000
# 25%          82.000000
# 50%         154.000000
# 75%         227.000000
# max         299.000000
# Name: Vintage, dtype: float64
# **************************************************
# Object type:int64
# **************************************************

# %%
get_report(train_df, 'Annual_Premium')
# Out:
# Description:
# count    381109.000000
# mean      30564.389581
# std       17213.155057
# min        2630.000000
# 25%       24405.000000
# 50%       31669.000000
# 75%       39400.000000
# max      540165.000000
# Name: Annual_Premium, dtype: float64
# **************************************************
# Object type:float64
# **************************************************

# %%
get_report(train_df, 'Policy_Sales_Channel')
# Out:
# Description:
# count    381109.000000
# mean        112.034295
# std          54.203995
# min           1.000000
# 25%          29.000000
# 50%         133.000000
# 75%         152.000000
# max         163.000000
# Name: Policy_Sales_Channel, dtype: float64
# **************************************************
# Object type:float64
# **************************************************

# %% [markdown]
# ### `EDA on Vehicle Damage`

# %%
damage_1 = train_df[train_df['Vehicle_Damage'] == 'Yes']
damage_0 = train_df[train_df['Vehicle_Damage'] == 'No']

# %%
get_report(damage_1, 'Gender')
# Out:
# Description:
# count     192413
# unique         2
# top         Male
# freq      112748
# Name: Gender, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#          Count  Frequency %
# Male    112748    58.596872
# Female   79665    41.403128
# **************************************************

# %%
get_report(damage_0, 'Gender')
# Out:
# Description:
# count     188696
# unique         2
# top       Female
# freq       95355
# Name: Gender, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#         Count  Frequency %
# Female  95355    50.533663
# Male    93341    49.466337
# **************************************************

# %%
def get_report_2(df, feature, hue):
    match feature:
        case 'Age' | 'Region_Code' | 'Annual_Premium' | 'Policy_Sales_Channel' | 'Vintage':
            figure(figsize=(20, 8)) 
            sns.kdeplot(x=feature, hue=hue, palette = 'Set2', shade=True, data=df)
        case 'Vehicle_Damage' | 'Previously_Insured':
            figure(figsize=(20, 8))
            sns.countplot(x = feature, hue = hue , palette = 'Set2', data = df)
        case _:
            print("Error")

# %%
get_report_2(train_df, 'Age', 'Response')

# %%
get_report_2(train_df, 'Region_Code', 'Response')

# %%
get_report_2(train_df, 'Annual_Premium', 'Response')

# %%
get_report_2(train_df, 'Vintage', 'Response')

# %%
get_report_2(train_df, 'Policy_Sales_Channel', 'Response')

# %%
get_report_2(train_df, 'Vehicle_Damage', 'Response')

# %%
get_report_2(train_df, 'Vehicle_Damage', 'Vehicle_Age')

# %%
get_report_2(train_df, 'Vehicle_Damage', 'Driving_License')

# %%
get_report_2(train_df, 'Vintage', 'Vehicle_Damage')

# %%
get_report_2(train_df, 'Vehicle_Damage', 'Gender')

# %%
get_report_2(train_df, 'Vehicle_Damage', 'Previously_Insured')

# %%
get_report_2(train_df, 'Previously_Insured', 'Vehicle_Age')

# %%
figure(figsize=(20, 8))
train_df.boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## `Transform Data`

# %%
train_df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
def drop_features(df, feature):
    df = df.drop([feature], axis=1, inplace=True)
    return df

# %%
drop_features(train_df, 'id')

# %%
class encoding(BaseEstimator, TransformerMixin):
    def __init__(self, column_2=['Vehicle_Age', 'Vehicle_Damage', 'Gender']):
        self.column_2 = column_2
    def fit(self, df):
        return self
    def transform(self, df):
        oe = OrdinalEncoder()
        df[self.column_2] = oe.fit_transform(df[self.column_2])
        return df

# %%
class feature_scaling(BaseEstimator, TransformerMixin):
    def __init__(self, column_3=['Annual_Premium']):
        self.column_3 = column_3
    def fit(self, df):
        return self
    def transform(self, df):
        if (set(self.column_3).issubset(df.columns)):
            min_max = MinMaxScaler()
            df[self.column_3] = min_max.fit_transform(df[self.column_3])
            return df
        else:
            print("Error")
            return df

# %%
pipe = Pipeline([
    ('encode', encoding()),
    ('scaler', feature_scaling()),
])

# %%
pipe
# Out:
# Pipeline(steps=[('encode', encoding()), ('scaler', feature_scaling())])

# %%
pipe.fit_transform(train_df)
# Out:
#         Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0          1.0   44                1         28.0                   0
# 1          1.0   76                1          3.0                   0
# 2          1.0   47                1         28.0                   0
# 3          1.0   21                1         11.0                   1
# 4          0.0   29                1         41.0                   1
# ...        ...  ...              ...          ...                 ...
# 381104     1.0   74                1         26.0                   1
# 381105     1.0   30                1         37.0                   1
# 381106     1.0   21                1         30.0                   1
# 381107     0.0   68                1         14.0                   0
# 381108     1.0   46                1         29.0                   0
#
#         Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0               2.0             1.0        0.070366                  26.0
# 1               0.0             0.0        0.057496                  26.0
# 2               2.0             1.0        0.066347                  26.0
# 3               1.0             0.0        0.048348                 152.0
# 4               1.0             0.0        0.046259                 152.0
# ...             ...             ...             ...                   ...
# 381104          0.0             0.0        0.051234                  26.0
# 381105          1.0             0.0        0.069551                 152.0
# 381106          1.0             0.0        0.060439                 160.0
# 381107          2.0             1.0        0.078110                 124.0
# 381108          0.0             0.0        0.072827                  26.0
#
#         Vintage  Response
# 0           217         1
# 1           183         0
# 2            27         1
# 3           203         0
# 4            39         0
# ...         ...       ...
# 381104       88         0
# 381105      131         0
# 381106      161         0
# 381107       74         0
# 381108      237         0
#
# [381109 rows x 11 columns]

# %%
def outlier_thresholds_iqr(df, feature, th1, th3):
    Q1 = df[feature].quantile(th1)
    Q3 = df[feature].quantile(th3)
    IQR = Q3 - Q1
    upper_limit = Q3 + 3 * IQR
    lower_limit = Q1 - 1 * IQR
    return upper_limit, lower_limit

# %%
for i in train_df.columns:
    if i != 'Outcome':
        print('################################')
        print(i, ":", outlier_thresholds_iqr(train_df, i, th1=0.05, th3=0.95))
    else:
        pass
# Out:
# ################################
# Gender : (4.0, -1.0)
# ################################
# Age : (213.0, -27.0)
# ################################
# Driving_License : (1.0, 1.0)
# ################################
# Region_Code : (173.0, -37.0)
# ################################
# Previously_Insured : (4.0, -1.0)
# ################################
# Vehicle_Age : (4.0, -1.0)
# ################################
# Vehicle_Damage : (4.0, -1.0)
# ################################
# Annual_Premium : (0.39101453858818497, -0.09775363464704624)
# ################################
# Policy_Sales_Channel : (562.0, -108.0)
# ################################
# Vintage : (1068.0, -237.0)
# ################################
# Response : (4.0, -1.0)

# %%
def check_outliers_iqr(df, feature):
    upper_limit, lower_limit = outlier_thresholds_iqr(df, feature, th1=0.05, th3=0.95)
    if df[(df[feature] > upper_limit) | (df[feature] < lower_limit)].any(axis=None):
        return True
    else:
        return False

# %%
from tabulate import tabulate
def replace_with_thresholds_iqr(df, features, th1=0.05, th3=0.95, replace=True):
    data = []
    for feature in features:
        if feature != 'Response':
            outliers = check_outliers_iqr(df, feature)
            count = None
            upper_limit, lower_limit = outlier_thresholds_iqr(df, feature, th1=0.05, th3=0.95)
            if outliers:
                count = df[(df[feature] > upper_limit) | (df[feature] < lower_limit)][feature].count()
                if replace:
                    if lower_limit < 0:
                        df.loc[(df[feature] > upper_limit), feature] = upper_limit
                    else:
                        df.loc[(df[feature] < lower_limit), feature] = lower_limit
                        df.loc[(df[feature] > upper_limit), feature] = upper_limit
            outliers_status = check_outliers_iqr(df, feature)
            data.append([outliers, outliers_status, count, feature, upper_limit, lower_limit ])
    table = tabulate(data, headers=['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured',
       'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
       'Policy_Sales_Channel', 'Vintage'], tablefmt='rst', numalign='right')
    print(table)


replace_with_thresholds_iqr(train_df, train_df.columns, th1=0.05, th3=0.95)
# Out:
# ========  =====  =================  ====================  ====================  =============
# Gender    Age      Driving_License  Region_Code             Previously_Insured    Vehicle_Age
# ========  =====  =================  ====================  ====================  =============
# False     False                     Gender                                   4             -1
# False     False                     Age                                    213            -27
# True      False                812  Driving_License                          1              1
# False     False                     Region_Code                            173            -37
# False     False                     Previously_Insured                       4             -1
# False     False                     Vehicle_Age                              4             -1
# False     False                     Vehicle_Damage                           4             -1
# True      False                106  Annual_Premium                    0.391015     -0.0977536
# False     False                     Policy_Sales_Channel                   562           -108
# False     False                     Vintage                               1068           -237
# ========  =====  =================  ====================  ====================  =============

# %%
label = [0, 1]
plt.pie(train_df['Response'].value_counts(), labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
donut_plot = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(donut_plot)

# %%
train_df.skew()
# Out:
# Gender                 -0.163590
# Age                     0.672539
# Driving_License         0.000000
# Region_Code            -0.115266
# Previously_Insured      0.167747
# Vehicle_Age             0.589682
# Vehicle_Damage         -0.019507
# Annual_Premium          0.605944
# Policy_Sales_Channel   -0.900008
# Vintage                 0.003030
# Response                2.301906
# dtype: float64

# %%
def create_kde_plot(df, feature):
    sns.kdeplot(data=df, x=feature)

# %%
list = []
for k in train_df.columns:
    list += [k]

# %%
figure(figsize=(20, 12))
count = 8
for i in range(count):
    plt.subplot(4, 4, i+1)
    create_kde_plot(train_df, list[i])

# %%
train_df = train_df.sample(n=50000)

# %%
train_df.shape
# Out:
# (50000, 11)

# %%
x = train_df.iloc[:, :-1]
y = train_df.iloc[:, -1]

# %%
smote = SMOTE(random_state=42)
x, y = smote.fit_resample(x, y)

# %%
label = [0, 1]
plt.pie(y.value_counts(), labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
donut_plot = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(donut_plot)

# %%
x.shape
# Out:
# (87610, 10)

# %%
figure(figsize=(20, 12))
mask = np.zeros_like(x.corr('spearman'))
mask[np.triu_indices_from(mask)] = True
sns.heatmap(x.corr('spearman'), annot=True, cmap='flare', linewidths=.5, mask=mask)
# Out:
# <AxesSubplot: >

# %%
models = {
    'Logistic_Regression': LogisticRegression(C=0.04, penalty='l2', solver='lbfgs'),
    'Navie_Bayes': GaussianNB(),
    'Multi_navie_bayes': MultinomialNB(),
    'Random_Forest': RandomForestClassifier(n_estimators=100, criterion='gini'),
    'ada_boost': AdaBoostClassifier(),
    'gradient_boost': GradientBoostingClassifier(),
    'Bagging_Classifer': BaggingClassifier(n_estimators=500, max_features=0.5, max_samples=1.0),
    'knn_classifier': KNeighborsClassifier(n_neighbors=2),
    'Decision_tree': DecisionTreeClassifier(),
    'Extr_tree': ExtraTreesClassifier(n_estimators = 100, criterion = 'gini', random_state = 0),
}

# %%
def explainable_ai(model):
    match model:
        case GaussianNB() | BaggingClassifier() | MultinomialNB() | KNeighborsClassifier():
            print("Not suported")
        case _:
            fig_1 = FeatureImportances(model)
            fig_1.fit(x_train, y_train)
            fig_1.show()
            visualizer = ROCAUC(model)
            visualizer.fit(x_train, y_train)     
            visualizer.score(x_test, y_test)        
            visualizer.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
def train_model(model, model_name, x=x_train, y=y_train, x_test = x_test):
    print("##########################################################################")
    model = model.fit(x, y)
    y_pred = model.predict(x_test)
    print(model_name, ":", accuracy_score(y_test, y_pred))
    print("--------------------------------------------------------------------------")
    print('--------------------------------------------------------------------------')
    report = classification_report(y_test, y_pred)
    print(report)
    explainable_ai(model)

# %%
for model_name, model in models.items():
    train_model(model, model_name)
# Out:
# ##########################################################################
# Logistic_Regression : 0.7830156374843055
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.59      0.73     13150
#            1       0.70      0.98      0.82     13133
#
#     accuracy                           0.78     26283
#    macro avg       0.83      0.78      0.77     26283
# weighted avg       0.83      0.78      0.77     26283
# ##########################################################################
# Navie_Bayes : 0.7834341589620667
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.59      0.73     13150
#            1       0.70      0.98      0.82     13133
#
#     accuracy                           0.78     26283
#    macro avg       0.83      0.78      0.77     26283
# weighted avg       0.83      0.78      0.77     26283
#
# Not suported
# ##########################################################################
# Multi_navie_bayes : 0.6167484685918655
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64     13150
#            1       0.64      0.54      0.59     13133
#
#     accuracy                           0.62     26283
#    macro avg       0.62      0.62      0.61     26283
# weighted avg       0.62      0.62      0.61     26283
#
# Not suported
# ##########################################################################
# Random_Forest : 0.9083437963702774
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     13150
#            1       0.90      0.92      0.91     13133
#
#     accuracy                           0.91     26283
#    macro avg       0.91      0.91      0.91     26283
# weighted avg       0.91      0.91      0.91     26283
# ##########################################################################
# ada_boost : 0.8454894798919453
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.84     13150
#            1       0.81      0.91      0.85     13133
#
#     accuracy                           0.85     26283
#    macro avg       0.85      0.85      0.84     26283
# weighted avg       0.85      0.85      0.84     26283
# ##########################################################################
# gradient_boost : 0.8607084427196287
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85     13150
#            1       0.83      0.91      0.87     13133
#
#     accuracy                           0.86     26283
#    macro avg       0.86      0.86      0.86     26283
# weighted avg       0.86      0.86      0.86     26283
# ##########################################################################
# Bagging_Classifer : 0.9067838526804398
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90     13150
#            1       0.89      0.93      0.91     13133
#
#     accuracy                           0.91     26283
#    macro avg       0.91      0.91      0.91     26283
# weighted avg       0.91      0.91      0.91     26283
#
# Not suported
# ##########################################################################
# knn_classifier : 0.8508922116957729
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85     13150
#            1       0.84      0.86      0.85     13133
#
#     accuracy                           0.85     26283
#    macro avg       0.85      0.85      0.85     26283
# weighted avg       0.85      0.85      0.85     26283
#
# Not suported
# ##########################################################################
# Decision_tree : 0.8783624395997413
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88     13150
#            1       0.87      0.89      0.88     13133
#
#     accuracy                           0.88     26283
#    macro avg       0.88      0.88      0.88     26283
# weighted avg       0.88      0.88      0.88     26283
# ##########################################################################
# Extr_tree : 0.9133280066963436
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91     13150
#            1       0.90      0.93      0.91     13133
#
#     accuracy                           0.91     26283
#    macro avg       0.91      0.91      0.91     26283
# weighted avg       0.91      0.91      0.91     26283

# %% [markdown]
# ## `Deep Learning`

# %%
import tensorflow as tf

# %%
model_dl = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(1, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.l2(l2=0.01))
    ])

# %%
model_dl.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                 loss=tf.keras.losses.BinaryCrossentropy(),
                 metrics=['accuracy'])

# %%
cb_list = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)] #tf.keras.callbacks.TensorBoard(log_dir='../logs', histogram_freq=1)]

# %%
history = model_dl.fit(x_train, y_train,
                   epochs=100,
                   validation_split=0.3, callbacks=cb_list)
# Out:
# Epoch 1/100
# 2693/2693 [==============================] - 30s 11ms/step - loss: 0.5469 - accuracy: 0.7153 - val_loss: 0.4399 - val_accuracy: 0.7845
# Epoch 2/100
# 2693/2693 [==============================] - 28s 10ms/step - loss: 0.4444 - accuracy: 0.7838 - val_loss: 0.4353 - val_accuracy: 0.7866
# Epoch 3/100
# 2693/2693 [==============================] - 29s 11ms/step - loss: 0.4377 - accuracy: 0.7870 - val_loss: 0.4369 - val_accuracy: 0.7809
# Epoch 4/100
# 2693/2693 [==============================] - 29s 11ms/step - loss: 0.4335 - accuracy: 0.7900 - val_loss: 0.4229 - val_accuracy: 0.7957
# Epoch 5/100
# 2693/2693 [==============================] - 29s 11ms/step - loss: 0.4316 - accuracy: 0.7907 - val_loss: 0.4332 - val_accuracy: 0.7866
# Epoch 6/100
# 2693/2693 [==============================] - 27s 10ms/step - loss: 0.4280 - accuracy: 0.7920 - val_loss: 0.4222 - val_accuracy: 0.7962
# Epoch 7/100
# 2693/2693 [==============================] - 25s 9ms/step - loss: 0.4286 - accuracy: 0.7930 - val_loss: 0.4280 - val_accuracy: 0.7912
# Epoch 8/100
# Epoch 66/100
# 2693/2693 [==============================] - 30s 11ms/step - loss: 0.4009 - accuracy: 0.8027 - val_loss: 0.4034 - val_accuracy: 0.7968
# Epoch 67/100
# 2693/2693 [==============================] - 26s 10ms/step - loss: 0.4008 - accuracy: 0.8037 - val_loss: 0.3967 - val_accuracy: 0.8008
# Epoch 68/100
# 2693/2693 [==============================] - 24s 9ms/step - loss: 0.3972 - accuracy: 0.8046 - val_loss: 0.4076 - val_accuracy: 0.7955
# Epoch 69/100
# 2693/2693 [==============================] - 27s 10ms/step - loss: 0.4023 - accuracy: 0.8028 - val_loss: 0.4013 - val_accuracy: 0.7992
# Epoch 70/100
# 2693/2693 [==============================] - 26s 10ms/step - loss: 0.3964 - accuracy: 0.8055 - val_loss: 0.4034 - val_accuracy: 0.7976
# Epoch 71/100
# 2693/2693 [==============================] - 27s 10ms/step - loss: 0.3980 - accuracy: 0.8052 - val_loss: 0.4142 - val_accuracy: 0.7914
# Epoch 72/100
# 2693/2693 [==============================] - 28s 10ms/step - loss: 0.3977 - accuracy: 0.8045 - val_loss: 0.3974 - val_accuracy: 0.7976
# Epoch 73/100
# 2693/2693 [==============================] - 29s 11ms/step - loss: 0.3973 - accuracy: 0.8051 - val_loss: 0.4032 - val_accuracy: 0.7930
# Epoch 74/100
# 2693/2693 [==============================] - 29s 11ms/step - loss: 0.3988 - accuracy: 0.8018 - val_loss: 0.4024 - val_accuracy: 0.7932
# Epoch 75/100
# 2693/2693 [==============================] - 28s 10ms/step - loss: 0.3999 - accuracy: 0.8035 - val_loss: 0.4021 - val_accuracy: 0.8021
# Epoch 76/100
# 2693/2693 [==============================] - 25s 9ms/step - loss: 0.3964 - accuracy: 0.8060 - val_loss: 0.4041 - val_accuracy: 0.7979
# Epoch 77/100
# 2693/2693 [==============================] - 26s 10ms/step - loss: 0.4007 - accuracy: 0.8044 - val_loss: 0.4060 - val_accuracy: 0.7939
# Epoch 78/100
# 2693/2693 [==============================] - 28s 10ms/step - loss: 0.3984 - accuracy: 0.8030 - val_loss: 0.4009 - val_accuracy: 0.7980
# Epoch 79/100
# 2693/2693 [==============================] - 28s 10ms/step - loss: 0.3984 - accuracy: 0.8046 - val_loss: 0.4095 - val_accuracy: 0.7984

# %%
figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
figure(figsize=(20, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model_dl.evaluate(x_train, y_train)
# Out:
# 3847/3847 [==============================] - 15s 4ms/step - loss: 0.4075 - accuracy: 0.7991
# [0.4075401723384857, 0.7991322875022888]

# %%
model_dl.evaluate(x_test, y_test)
# Out:
# 1649/1649 [==============================] - 6s 4ms/step - loss: 0.4092 - accuracy: 0.7980
# [0.40924936532974243, 0.7979866862297058]

# %% [markdown]
# ## `Top-4 Models`

# %% [markdown]
# * RandomForestClassifier : 90%
# * BaggingClassifier      : 90%
# * DecisionTreeClassifier : 87%
# * ExtraTreesClassifier   : 91%

# %% [markdown]
# ### `Model Tuining`

# %% [markdown]
# ## `Model tuning and Runnning is present on github actions`

# %% [markdown]
# link: https://github.com/dev-hack95/health_insurance_cross_sell_prediction/actions
